# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("C:/Users/HIMANSHUU/Desktop/Courses/udemy ml course/practice 1/world-happiness-report.csv",header=0)

# %%
df.head()
# Out:
#   Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions of corruption  Positive affect  Negative affect
# ...

# %%
df.columns = df.columns.str.replace(' ','_')

# %%
df.head()
# Out:
#   Country_name  year  Life_Ladder  Log_GDP_per_capita  Social_support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy_life_expectancy_at_birth  Freedom_to_make_life_choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions_of_corruption  Positive_affect  Negative_affect
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      Country_name  year  Life_Ladder  Log_GDP_per_capita  Social_support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
# ...

# %%
df.shape
# Out:
# (1949, 11)

# %%
df.describe()
# Out:
#               year  Life_Ladder  Log_GDP_per_capita  Social_support  \
# count  1949.000000  1949.000000         1913.000000     1936.000000
# mean   2013.216008     5.466705            9.368453        0.812552
# std       4.166828     1.115711            1.154084        0.118482
# min    2005.000000     2.375000            6.635000        0.290000
# 25%    2010.000000     4.640000            8.464000        0.749750
# 50%    2013.000000     5.386000            9.460000        0.835500
# 75%    2017.000000     6.283000           10.353000        0.905000
# max    2020.000000     8.019000           11.648000        0.987000
#
#        Healthy_life_expectancy_at_birth  Freedom_to_make_life_choices  \
# count                       1894.000000                   1917.000000
# mean                          63.359374                      0.742558
# std                            7.510245                      0.142093
# min                           32.300000                      0.258000
# ...

# %%
df.Log_GDP_per_capita = df.Log_GDP_per_capita.fillna(df.Log_GDP_per_capita.mean())

# %%
df.describe()
# Out:
#               year  Life_Ladder  Log_GDP_per_capita  Social_support  \
# count  1949.000000  1949.000000         1949.000000     1936.000000
# mean   2013.216008     5.466705            9.368453        0.812552
# std       4.166828     1.115711            1.143370        0.118482
# min    2005.000000     2.375000            6.635000        0.290000
# 25%    2010.000000     4.640000            8.478000        0.749750
# 50%    2013.000000     5.386000            9.443000        0.835500
# 75%    2017.000000     6.283000           10.335000        0.905000
# max    2020.000000     8.019000           11.648000        0.987000
#
#        Healthy_life_expectancy_at_birth  Freedom_to_make_life_choices  \
# count                       1894.000000                   1917.000000
# mean                          63.359374                      0.742558
# std                            7.510245                      0.142093
# min                           32.300000                      0.258000
# ...

# %%
np.nanpercentile(df.Generosity,[90])
# Out:
# array([0.2331])

# %%
df = df.fillna(df.mean())

# %%
df.describe()
# Out:
#               year  Life_Ladder  Log_GDP_per_capita  Social_support  \
# count  1949.000000  1949.000000         1949.000000     1949.000000
# mean   2013.216008     5.466705            9.368453        0.812552
# std       4.166828     1.115711            1.143370        0.118086
# min    2005.000000     2.375000            6.635000        0.290000
# 25%    2010.000000     4.640000            8.478000        0.751000
# 50%    2013.000000     5.386000            9.443000        0.834000
# 75%    2017.000000     6.283000           10.335000        0.905000
# max    2020.000000     8.019000           11.648000        0.987000
#
#        Healthy_life_expectancy_at_birth  Freedom_to_make_life_choices  \
# count                       1949.000000                   1949.000000
# mean                          63.359374                      0.742558
# std                            7.403463                      0.140921
# min                           32.300000                      0.258000
# ...

# %%
df.corr()
# Out:
#                                       year  Life_Ladder  Log_GDP_per_capita  \
# year                              1.000000     0.035515            0.077311
# Life_Ladder                       0.035515     1.000000            0.783824
# Log_GDP_per_capita                0.077311     0.783824            1.000000
# Social_support                   -0.010069     0.705356            0.682438
# Healthy_life_expectancy_at_birth  0.162174     0.741200            0.834455
# Freedom_to_make_life_choices      0.220102     0.525844            0.361404
# Generosity                       -0.041429     0.186132           -0.000901
# Perceptions_of_corruption        -0.079233    -0.419349           -0.333645
# Positive_affect                  -0.003227     0.530459            0.297011
# Negative_affect                   0.195926    -0.296786           -0.204615
#
#                                   Social_support  \
# year                                   -0.010069
# ...

# %%
del df['Negative_affect']

# %%
df.head()
# Out:
#   Country_name  year  Life_Ladder  Log_GDP_per_capita  Social_support  \
# 0  Afghanistan  2008        3.724               7.370           0.451
# 1  Afghanistan  2009        4.402               7.540           0.552
# 2  Afghanistan  2010        4.758               7.647           0.539
# 3  Afghanistan  2011        3.832               7.620           0.521
# 4  Afghanistan  2012        3.783               7.705           0.521
#
#    Healthy_life_expectancy_at_birth  Freedom_to_make_life_choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions_of_corruption  Positive_affect
# ...

# %%
del df['Country_name']

# %%
del df['year']

# %%
df.head()
# Out:
#    Life_Ladder  Log_GDP_per_capita  Social_support  \
# 0        3.724               7.370           0.451
# 1        4.402               7.540           0.552
# 2        4.758               7.647           0.539
# 3        3.832               7.620           0.521
# 4        3.783               7.705           0.521
#
#    Healthy_life_expectancy_at_birth  Freedom_to_make_life_choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions_of_corruption  Positive_affect
# 0                      0.882            0.518
# 1                      0.850            0.584
# 2                      0.707            0.618
# ...

# %%
df.corr()
# Out:
#                                   Life_Ladder  Log_GDP_per_capita  \
# Life_Ladder                          1.000000            0.783824
# Log_GDP_per_capita                   0.783824            1.000000
# Social_support                       0.705356            0.682438
# Healthy_life_expectancy_at_birth     0.741200            0.834455
# Freedom_to_make_life_choices         0.525844            0.361404
# Generosity                           0.186132           -0.000901
# Perceptions_of_corruption           -0.419349           -0.333645
# Positive_affect                      0.530459            0.297011
#
#                                   Social_support  \
# Life_Ladder                             0.705356
# Log_GDP_per_capita                      0.682438
# Social_support                          1.000000
# Healthy_life_expectancy_at_birth        0.613854
# Freedom_to_make_life_choices            0.408765
# Generosity                              0.065510
# ...

# %%
import statsmodels.api as sn

# %%
X = sn.add_constant(df['Generosity'])

# %%
lm = sn.OLS(df['Positive_affect'],X).fit()

# %%
from sklearn.linear_model import LinearRegression

# %%
y = df['Positive_affect']
X = df[['Generosity']]

# %%
lm2 = LinearRegression()

# %%
lm2.fit(X,y)
# Out:
# LinearRegression()

# %%
print(lm2.intercept_,lm2.coef_)
# Out:
# 0.7099788559821529 [0.23499614]

# %%
lm2.predict(X)
# Out:
# array([0.74945821, 0.75462812, 0.73841339, ..., 0.69399912, 0.6949391 ,
#        0.70786389])

# %%
sns.jointplot(x=df['Generosity'],y=df['Positive_affect'],data=df,kind='reg')

# %%
print(lm)

# %%
import statsmodels.api as sn

# %%
X_multi = df.drop('Positive_affect',axis=1)

# %%
X_multi.head()
# Out:
#    Life_Ladder  Log_GDP_per_capita  Social_support  \
# 0        3.724               7.370           0.451
# 1        4.402               7.540           0.552
# 2        4.758               7.647           0.539
# 3        3.832               7.620           0.521
# 4        3.783               7.705           0.521
#
#    Healthy_life_expectancy_at_birth  Freedom_to_make_life_choices  Generosity  \
# 0                             50.80                         0.718       0.168
# 1                             51.20                         0.679       0.190
# 2                             51.60                         0.600       0.121
# 3                             51.92                         0.496       0.162
# 4                             52.24                         0.531       0.236
#
#    Perceptions_of_corruption
# 0                      0.882
# 1                      0.850
# 2                      0.707
# 3                      0.731
# 4                      0.776

# %%
y_multi = df['Positive_affect']

# %%
y_multi.head()
# Out:
# 0    0.518
# 1    0.584
# 2    0.618
# 3    0.611
# 4    0.710
# Name: Positive_affect, dtype: float64

# %%
X_multi_cons = sn.add_constant(X_multi)

# %%
X_multi_cons
# Out:
#       const  Life_Ladder  Log_GDP_per_capita  Social_support  \
# 0       1.0        3.724               7.370           0.451
# 1       1.0        4.402               7.540           0.552
# 2       1.0        4.758               7.647           0.539
# 3       1.0        3.832               7.620           0.521
# 4       1.0        3.783               7.705           0.521
# ...     ...          ...                 ...             ...
# 1944    1.0        3.735               7.984           0.768
# 1945    1.0        3.638               8.016           0.754
# 1946    1.0        3.616               8.049           0.775
# 1947    1.0        2.694               7.950           0.759
# 1948    1.0        3.160               7.829           0.717
#
#       Healthy_life_expectancy_at_birth  Freedom_to_make_life_choices  \
# 0                                50.80                         0.718
# 1                                51.20                         0.679
# ...

# %%
lm_multi = sn.OLS(y_multi,X_multi_cons).fit()

# %%
lm_multi.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Positive_affect   R-squared:                       0.483
# Model:                            OLS   Adj. R-squared:                  0.481
# Method:                 Least Squares   F-statistic:                     259.0
# Date:                Fri, 09 Apr 2021   Prob (F-statistic):          1.29e-272
# Time:                        11:37:37   Log-Likelihood:                 2243.0
# No. Observations:                1949   AIC:                            -4470.
# Df Residuals:                    1941   BIC:                            -4425.
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# ...

# %%
lm3 = LinearRegression()

# %%
lm3.fit(X_multi,y_multi)
# Out:
# LinearRegression()

# %%
print(lm3.intercept_,lm3.coef_)
# Out:
# 0.3587091145932423 [ 0.03920395 -0.02119109  0.14142663 -0.00047241  0.30071604  0.10311927
#   0.03642075]

# %%
sns.jointplot(x=X_multi,y=y_multi,data=df,kind='reg')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in create_block_manager_from_arrays(arrays, names, axes)
#    1682     try:
# -> 1683         blocks = form_blocks(arrays, names, axes)
#    1684         mgr = BlockManager(blocks, axes)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in form_blocks(arrays, names, axes)
#    1771     if len(items_dict["ObjectBlock"]) > 0:
# -> 1772         object_blocks = _simple_blockify(items_dict["ObjectBlock"], np.object_)
#    1773         blocks.extend(object_blocks)
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _simple_blockify(tuples, dtype)
#    1816     """
# -> 1817     values, placement = _stack_arrays(tuples, dtype)
#    1818
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in _stack_arrays(tuples, dtype)
# ...

# %%
lm3.predict(X_multi)
# Out:
# array([0.65367242, 0.68012058, 0.65370226, ..., 0.66641638, 0.59036719,
#        0.61242675])

# %%
sns.jointplot(x=lm3.predict(X_multi),y=y_multi,kind='reg')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X_multi,y_multi,test_size=0.2,random_state = 0)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (1559, 7) (390, 7) (1559,) (390,)

# %%
lm_a = LinearRegression()

# %%
lm_a.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_test_a = lm_a.predict(X_test)
y_train_a = lm_a.predict(X_train)

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_test_a)
# Out:
# 0.46884088977209937

# %%
r2_score(y_train,y_train_a)
# Out:
# 0.4861772446455014

# %%
r2_score?

# %%
y_test_a
# Out:
# array([0.65831055, 0.65263891, 0.73466717, 0.77906225, 0.76497856,
#        0.66080372, 0.68202821, 0.66642452, 0.73291309, 0.73293095,
#        0.62781591, 0.72631627, 0.83677049, 0.72964451, 0.83964568,
#        0.70272356, 0.77436514, 0.69475299, 0.78448641, 0.79222179,
#        0.75144235, 0.80257114, 0.75638418, 0.82123612, 0.62467541,
#        0.82497622, 0.75939715, 0.64878943, 0.86485087, 0.58306338,
#        0.60354432, 0.73569325, 0.7215803 , 0.69707784, 0.77222207,
#        0.74038498, 0.54032437, 0.83976502, 0.76203515, 0.7329579 ,
#        0.83968553, 0.71854752, 0.84290826, 0.76132462, 0.613781  ,
#        0.75788924, 0.69841807, 0.70623793, 0.58364629, 0.80450836,
#        0.54369954, 0.67867513, 0.7166404 , 0.66760805, 0.66282902,
#        0.67465612, 0.65683974, 0.64398322, 0.62239909, 0.70208154,
#        0.65365995, 0.63207605, 0.71730021, 0.78404417, 0.62963107,
#        0.64809348, 0.68418227, 0.68512202, 0.75515994, 0.62193126,
# ...

# %%
y_test
# Out:
# 18      0.685
# 1520    0.513
# 1437    0.734
# 187     0.786
# 333     0.815
#         ...
# 459     0.836
# 1330    0.567
# 899     0.702
# 1616    0.709
# 253     0.579
# Name: Positive_affect, Length: 390, dtype: float64

# %%
y_train
# Out:
# pandas.core.series.Series

# %%
y_train_new = y_train.round()

# %%
from sklearn.linear_model import LogisticRegression
clf_lrs = LinearRegression()

# %%
X_train_new = X_train
clf_lrs.fit(X_train_new,y_train_new)
# Out:
# LinearRegression()

# %%
clf_lrs.intercept_
# Out:
# 0.7611938375306272

# %%
clf_lrs.coef_
# Out:
# array([ 0.03366361, -0.0204544 ,  0.08172821, -0.0015318 ,  0.22280088,
#         0.01163413,  0.11626273])

# %%
import statsmodels.api as sn

# %%
X_cons_new = sn.add_constant(X_train_new)

# %%
X_cons_new.head()
# Out:
#       const  Life_Ladder  Log_GDP_per_capita  Social_support  \
# 1031    1.0        3.816               7.334           0.673
# 299     1.0        7.415              10.744           0.948
# 1227    1.0        7.381              10.528           0.944
# 1069    1.0        3.676               7.599           0.820
# 521     1.0        5.857               8.986           0.798
#
#       Healthy_life_expectancy_at_birth  Freedom_to_make_life_choices  \
# 1031                             57.06                         0.480
# 299                              72.52                         0.918
# 1227                             71.60                         0.893
# 1069                             49.48                         0.665
# 521                              65.00                         0.778
#
#       Generosity  Perceptions_of_corruption
# 1031      -0.019                      0.868
# 299        0.290                      0.466
# 1227       0.298                      0.334
# ...
